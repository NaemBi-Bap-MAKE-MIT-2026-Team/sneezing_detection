# %%
# !ls work/out
# Out:
# hard_negs_v3	sneeze_ds_cnn_dynamic.tflite  threshold.txt
# norm_stats.npz	sneeze_ds_cnn.keras

# %%
# !pip -q install librosa soundfile tqdm scikit-learn

# %% [markdown]
# ## 셀 1. 경로/설정

# %%
from pathlib import Path
import random, numpy as np
import tensorflow as tf

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

WORK = Path("/content/work")

ESC50_DIR = WORK / "esc-50"
MS_SNSD_DIR = WORK / "MS-SNSD-NOISE"
SNEEZE_DIR = WORK / "sneeze"
REC_DIR = WORK / "recordings"

# 이미 존재하는 out 폴더를 그대로 사용
OUT_DIR = WORK / "out"
assert OUT_DIR.exists(), f"OUT_DIR not found: {OUT_DIR}"

# out 안의 파일명은 환경마다 다를 수 있으니, 아래 2줄만 out listing 보고 맞춰서 수정
V3_TFLITE = OUT_DIR / "sneeze_ds_cnn_dynamic.tflite"
V3_STATS  = OUT_DIR / "norm_stats.npz"

# v3 keras가 out에 있으면 이어학습 가능
V3_KERAS = OUT_DIR / "sneeze_ds_cnn.keras"

print("OUT_DIR:", OUT_DIR)
print("V3_TFLITE exists:", V3_TFLITE.exists(), V3_TFLITE)
print("V3_STATS exists:", V3_STATS.exists(), V3_STATS)
print("V3_KERAS exists:", V3_KERAS.exists(), V3_KERAS)

# 오디오 규격
SR = 16000
CLIP_SECONDS = 2.0
CLIP_SAMPLES = int(SR * CLIP_SECONDS)

# log-mel 파라미터(지금 실시간 코드와 동일해야 함)
N_MELS = 64
N_FFT = 400
HOP = 160

# 학습 때 쓰던 RMS 정규화 타겟(기존 파이프라인과 같게)
TARGET_RMS = 0.1
# Out:
# OUT_DIR: /content/work/out
# V3_TFLITE exists: True /content/work/out/sneeze_ds_cnn_dynamic.tflite
# V3_STATS exists: True /content/work/out/norm_stats.npz
# V3_KERAS exists: True /content/work/out/sneeze_ds_cnn.keras

# %% [markdown]
# ## 셀 2. 유틸(로드/2초 고정/특징/정규화)

# %%
def rms(x, eps=1e-8):
    x = np.asarray(x, np.float32)
    return float(np.sqrt(np.mean(x*x) + eps))

def normalize_rms(x, target=TARGET_RMS, eps=1e-8):
    x = np.asarray(x, np.float32)
    r = rms(x, eps=eps)
    if r > 1e-6:
        x = x * (target / (r + eps))
    return np.clip(x, -1.0, 1.0).astype(np.float32)

def load_wav_mono_16k(path: Path, sr=SR):
    y, _sr = librosa.load(str(path), sr=sr, mono=True)
    return y.astype(np.float32)

def fix_2s(y, n=CLIP_SAMPLES):
    y = np.asarray(y, np.float32)
    if len(y) >= n:
        return y[:n]
    return np.pad(y, (0, n - len(y))).astype(np.float32)

def logmel(y_16k_2s):
    S = librosa.feature.melspectrogram(
        y=y_16k_2s, sr=SR, n_fft=N_FFT, hop_length=HOP, n_mels=N_MELS, power=2.0
    )
    return np.log(S + 1e-6).T.astype(np.float32)  # (frames, mels)

def clip_from_long(y, start_sec, dur_sec=CLIP_SECONDS, sr=SR):
    s = int(start_sec * sr)
    e = s + int(dur_sec * sr)
    seg = y[s:e]
    return fix_2s(seg)

print("OK")
# Out:
# OK

# %% [markdown]
# ## 셀 3. v3 norm_stats 로드 + v3 전처리 함수

# %%
assert V3_STATS.exists(), f"v3 stats not found: {V3_STATS}"

st = np.load(str(V3_STATS), allow_pickle=True)
mu = st["mu"].astype(np.float32)
sd = st["sd"].astype(np.float32)

# (1,1,mels) -> (mels,)
if mu.ndim == 3 and mu.shape[0] == 1 and mu.shape[1] == 1:
    mu = mu.reshape(-1)
if sd.ndim == 3 and sd.shape[0] == 1 and sd.shape[1] == 1:
    sd = sd.reshape(-1)

# (1,frames,mels) -> (frames,mels)
if mu.ndim == 3 and mu.shape[0] == 1:
    mu = mu[0]
if sd.ndim == 3 and sd.shape[0] == 1:
    sd = sd[0]

def v3_preproc(y16_2s):
    y = fix_2s(y16_2s)
    y = normalize_rms(y)
    f = logmel(y)  # (frames,mels)
    fn = (f - mu) / (sd + 1e-6)
    return fn[None, ..., None].astype(np.float32)  # (1,frames,mels,1)

print("mu shape:", np.shape(mu), "sd shape:", np.shape(sd))
# Out:
# mu shape: (64,) sd shape: (64,)

# %% [markdown]
# ## 셀 4. v3 TFLite 로더

# %%
assert V3_TFLITE.exists(), f"v3 tflite not found: {V3_TFLITE}"

try:
    from tflite_runtime.interpreter import Interpreter as TFLiteInterpreter
except Exception:
    TFLiteInterpreter = tf.lite.Interpreter

class TFLiteModel:
    def __init__(self, path: Path):
        self.interp = TFLiteInterpreter(model_path=str(path))
        self.interp.allocate_tensors()
        self.in_det = self.interp.get_input_details()[0]
        self.out_det = self.interp.get_output_details()[0]

    def predict(self, x):
        self.interp.set_tensor(self.in_det["index"], x)
        self.interp.invoke()
        y = self.interp.get_tensor(self.out_det["index"]).reshape(-1)[0]
        return float(y)

tfl = TFLiteModel(V3_TFLITE)
print("v3 tflite ready")
# Out:
# v3 tflite ready
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %% [markdown]
# ## 셀 5. 하드 네거티브 마이닝

# %%
import soundfile as sf
import pandas as pd
from tqdm import tqdm
import librosa

rec_long_files = sorted([p for p in REC_DIR.rglob("*.wav")])
print("recordings wav:", len(rec_long_files))
for p in rec_long_files[:10]:
    print(" -", p)

HARD_DIR = OUT_DIR / "hard_negs_v3"
HARD_DIR.mkdir(parents=True, exist_ok=True)

def mine_hard_negs_from_long(path: Path, topk=60, hop_sec=0.25, min_rms=0.003, min_p=0.50):
    y = load_wav_mono_16k(path)
    if len(y) < CLIP_SAMPLES:
        return []

    hop = int(hop_sec * SR)
    scores = []

    for start in range(0, max(1, len(y) - CLIP_SAMPLES + 1), hop):
        seg = y[start:start+CLIP_SAMPLES]
        seg = fix_2s(seg)
        if rms(seg) < min_rms:
            continue
        x_in = v3_preproc(seg)
        p = tfl.predict(x_in)
        if p < min_p:
            continue
        scores.append((p, start / SR, seg))

    scores.sort(key=lambda x: x[0], reverse=True)

    picked = []
    for p, s, seg in scores:
        if len(picked) >= topk:
            break
        # 2초 간격 이상 떨어진 것만 채택(중복 방지)
        if all(abs(s - s2) >= 2.0 for _, s2, _ in picked):
            picked.append((p, s, seg))
    return picked

hard_meta = []
hard_neg_audio = []

TOPK_PER_FILE = 60
HOP_SEC = 0.25
MIN_RMS = 0.003
MIN_P = 0.50

for p in tqdm(rec_long_files, desc="hard neg mining v3"):
    picked = mine_hard_negs_from_long(p, topk=TOPK_PER_FILE, hop_sec=HOP_SEC, min_rms=MIN_RMS, min_p=MIN_P)
    for score, start_sec, seg in picked:
        out_wav = HARD_DIR / f"hardneg_{p.stem}_{start_sec:.2f}_p{score:.3f}.wav"
        sf.write(str(out_wav), seg, SR)
        hard_neg_audio.append(seg)
        hard_meta.append({
            "source":"hardneg_v3",
            "file": str(p),
            "start": float(start_sec),
            "score": float(score),
            "label": 0,
            "saved": str(out_wav),
            "rms": float(rms(seg)),
        })

print("hard negatives:", len(hard_neg_audio))
pd.DataFrame(hard_meta).sort_values("score", ascending=False).head(10)
# Out:
# recordings wav: 4
#  - /content/work/recordings/dish.wav
#  - /content/work/recordings/noise1.wav
#  - /content/work/recordings/noise2.wav
#  - /content/work/recordings/talk.wav
# hard neg mining v3: 100%|██████████| 4/4 [01:48<00:00, 27.16s/it]
# hard negatives: 211
#          source                                 file    start     score  \
# 0    hardneg_v3    /content/work/recordings/dish.wav   217.25  0.995522
# 60   hardneg_v3  /content/work/recordings/noise1.wav   483.25  0.994170
# 61   hardneg_v3  /content/work/recordings/noise1.wav   477.25  0.993641
# 62   hardneg_v3  /content/work/recordings/noise1.wav   481.25  0.992340
# 63   hardneg_v3  /content/work/recordings/noise1.wav   479.25  0.984472
# 64   hardneg_v3  /content/work/recordings/noise1.wav   485.50  0.974088
# 65   hardneg_v3  /content/work/recordings/noise1.wav   487.50  0.973766
# 1    hardneg_v3    /content/work/recordings/dish.wav   121.75  0.971508
# 2    hardneg_v3    /content/work/recordings/dish.wav    41.00  0.971018
# 151  hardneg_v3    /content/work/recordings/talk.wav  1504.25  0.970973
#
#      label                                              saved       rms
# 0        0  /content/work/out/hard_negs_v3/hardneg_dish_21...  0.063023
# 60       0  /content/work/out/hard_negs_v3/hardneg_noise1_...  0.072899
# 61       0  /content/work/out/hard_negs_v3/hardneg_noise1_...  0.083230
# 62       0  /content/work/out/hard_negs_v3/hardneg_noise1_...  0.074973
# 63       0  /content/work/out/hard_negs_v3/hardneg_noise1_...  0.090427
# 64       0  /content/work/out/hard_negs_v3/hardneg_noise1_...  0.057546
# 65       0  /content/work/out/hard_negs_v3/hardneg_noise1_...  0.075420
# 1        0  /content/work/out/hard_negs_v3/hardneg_dish_12...  0.047617
# 2        0  /content/work/out/hard_negs_v3/hardneg_dish_41...  0.032631
# 151      0  /content/work/out/hard_negs_v3/hardneg_talk_15...  0.138339

# %% [markdown]
# ## 셀 6. 기본 학습 데이터 로드(포지티브 + 기존 네거티브) + 하드 네거티브 추가

# %%
pos_files = sorted([p for p in SNEEZE_DIR.rglob("*.wav")])
esc_files = sorted([p for p in ESC50_DIR.rglob("*.wav")])
ms_files  = sorted([p for p in MS_SNSD_DIR.rglob("*.wav")])

print("pos:", len(pos_files), "esc:", len(esc_files), "ms:", len(ms_files), "hard:", len(hard_neg_audio))

def sample_neg_from_long_wav(path: Path, n_samples: int, min_rms: float = 0.003):
    y = load_wav_mono_16k(path)
    if len(y) < CLIP_SAMPLES:
        return []
    dur = len(y) / SR
    out = []
    tries = 0
    max_tries = n_samples * 30

    while len(out) < n_samples and tries < max_tries:
        tries += 1
        start = random.uniform(0, max(0.0, dur - CLIP_SECONDS))
        seg = clip_from_long(y, start)
        if rms(seg) < min_rms:
            continue
        out.append((seg, {"source": "recordings_rand", "file": str(path), "start": float(start), "rms": float(rms(seg)), "label": 0}))
    return out

def sample_neg_from_short_wav(path: Path):
    y = load_wav_mono_16k(path)
    seg = fix_2s(y)
    return seg, {"source": "shortwav", "file": str(path), "start": 0.0, "rms": float(rms(seg)), "label": 0}

# 1) 포지티브
pos_audio = []
meta_rows = []
for p in tqdm(pos_files, desc="load pos"):
    y = fix_2s(load_wav_mono_16k(p))
    pos_audio.append(y)
    meta_rows.append({"source":"sneeze", "file": str(p), "start": 0.0, "rms": float(rms(y)), "label": 1})

# 2) 네거티브 기본 풀: esc/ms + recordings 랜덤 + hard
neg_audio = []

# 네거티브 목표: pos*4 정도
POS_N = len(pos_audio)
NEG_TARGET = POS_N * 4

# hard neg는 가능한 많이 넣되, 너무 많으면 pos*2 정도로 제한
HARD_MAX = min(len(hard_neg_audio), POS_N * 2)
hard_sel = hard_neg_audio[:HARD_MAX]
neg_audio.extend(hard_sel)
for i, seg in enumerate(hard_sel):
    meta_rows.append({"source":"hardneg_v3", "file":"(from mining)", "start": 0.0, "rms": float(rms(seg)), "label": 0})

remaining = max(0, NEG_TARGET - len(neg_audio))
print("NEG_TARGET:", NEG_TARGET, "hard_used:", len(hard_sel), "remaining:", remaining)

# 나머지 네거티브는 recordings 랜덤 + esc/ms로 채움
neg_from_rec = int(remaining * 0.50)
neg_from_esc = int(remaining * 0.25)
neg_from_ms  = remaining - neg_from_rec - neg_from_esc

# recordings 랜덤 샘플
if len(rec_long_files) > 0 and neg_from_rec > 0:
    per_file = max(1, neg_from_rec // len(rec_long_files))
    for p in tqdm(rec_long_files, desc="neg rand from recordings"):
        segs = sample_neg_from_long_wav(p, n_samples=per_file, min_rms=0.003)
        for seg, info in segs:
            neg_audio.append(seg)
            meta_rows.append(info)
    # 부족하면 추가
    while len(neg_audio) < len(hard_sel) + neg_from_rec:
        p = random.choice(rec_long_files)
        segs = sample_neg_from_long_wav(p, n_samples=50, min_rms=0.003)
        for seg, info in segs:
            neg_audio.append(seg); meta_rows.append(info)
            if len(neg_audio) >= len(hard_sel) + neg_from_rec:
                break

# esc/ms 샘플
def add_from_pool(pool_files, target_n, source_name):
    if target_n <= 0 or len(pool_files) == 0:
        return
    for p in tqdm(random.sample(pool_files, min(len(pool_files), target_n)), desc=f"neg from {source_name}"):
        seg, info = sample_neg_from_short_wav(p)
        info["source"] = source_name
        neg_audio.append(seg)
        meta_rows.append(info)

add_from_pool(esc_files, neg_from_esc, "esc-50")
add_from_pool(ms_files,  neg_from_ms,  "ms-snsd")

print("pos_audio:", len(pos_audio), "neg_audio:", len(neg_audio))
# Out:
# pos: 968 esc: 2000 ms: 128 hard: 211
# load pos: 100%|██████████| 968/968 [00:00<00:00, 1368.58it/s]
# NEG_TARGET: 3872 hard_used: 211 remaining: 3661
# neg rand from recordings: 100%|██████████| 4/4 [00:03<00:00,  1.01it/s]
# neg from esc-50: 100%|██████████| 915/915 [00:06<00:00, 142.11it/s]
# neg from ms-snsd: 100%|██████████| 128/128 [00:03<00:00, 39.57it/s]
# pos_audio: 968 neg_audio: 3084

# %% [markdown]
# ## 셀 7. 특징 추출(반드시 v3 norm_stats로 정규화)

# %%
def feats_list(audio_list):
    feats = []
    for y in tqdm(audio_list, desc="logmel"):
        y = normalize_rms(fix_2s(y))
        f = logmel(y)
        fn = (f - mu) / (sd + 1e-6)
        feats.append(fn.astype(np.float32))
    return feats

pos_feats = feats_list(pos_audio)
neg_feats = feats_list(neg_audio)

X = np.array(pos_feats + neg_feats, dtype=np.float32)  # (N, frames, mels)
y = np.array([1]*len(pos_feats) + [0]*len(neg_feats), dtype=np.int64)

X = X[..., None]  # (N, frames, mels, 1)
print("X:", X.shape, "y:", y.shape, "pos:", int(y.sum()), "neg:", int((y==0).sum()))
# Out:
# logmel: 100%|██████████| 968/968 [00:02<00:00, 335.70it/s]
# logmel: 100%|██████████| 3084/3084 [00:11<00:00, 264.45it/s]
# X: (4052, 201, 64, 1) y: (4052,) pos: 968 neg: 3084

# %% [markdown]
# ## 셀 8. train/val/test 분할

# %%
from sklearn.model_selection import train_test_split

idx = np.arange(len(y))
idx_train, idx_tmp, y_train, y_tmp = train_test_split(idx, y, test_size=0.30, random_state=SEED, stratify=y)
idx_val, idx_test, y_val, y_test = train_test_split(idx_tmp, y_tmp, test_size=0.50, random_state=SEED, stratify=y_tmp)

X_train, X_val, X_test = X[idx_train], X[idx_val], X[idx_test]
y_train, y_val, y_test = y[idx_train], y[idx_val], y[idx_test]

print("train:", X_train.shape, "pos_rate:", float(y_train.mean()))
print("val:", X_val.shape, "pos_rate:", float(y_val.mean()))
print("test:", X_test.shape, "pos_rate:", float(y_test.mean()))
# Out:
# train: (2836, 201, 64, 1) pos_rate: 0.2390691114245416
# val: (608, 201, 64, 1) pos_rate: 0.23848684210526316
# test: (608, 201, 64, 1) pos_rate: 0.23848684210526316

# %% [markdown]
# ## 셀 9. 모델 정의(DS-CNN) + v3에서 이어학습

# %%
def ds_conv_block(x, filters, k=3, s=1, dropout=0.0):
    x = tf.keras.layers.DepthwiseConv2D((k,k), strides=(s,s), padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.Conv2D(filters, (1,1), padding="same", use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    if dropout > 0:
        x = tf.keras.layers.Dropout(dropout)(x)
    return x

def build_model(input_shape):
    inp = tf.keras.Input(shape=input_shape)

    x = tf.keras.layers.Conv2D(32, (3,3), strides=(2,2), padding="same", use_bias=False)(inp)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)

    x = ds_conv_block(x, 64,  k=3, s=1, dropout=0.05)
    x = ds_conv_block(x, 96,  k=3, s=2, dropout=0.05)
    x = ds_conv_block(x, 128, k=3, s=1, dropout=0.05)
    x = ds_conv_block(x, 160, k=3, s=2, dropout=0.05)
    x = ds_conv_block(x, 192, k=3, s=1, dropout=0.05)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    out = tf.keras.layers.Dense(1, activation="sigmoid")(x)
    return tf.keras.Model(inp, out)

if V3_KERAS.exists():
    model = tf.keras.models.load_model(str(V3_KERAS))
    print("Loaded v3 keras:", V3_KERAS)
else:
    model = build_model(X_train.shape[1:])
    print("Built new model (v3-like)")

model.summary()
# Out:
# Loaded v3 keras: /content/work/out/sneeze_ds_cnn.keras
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 201, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 201, 64, 16)    │            25 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 201, 64, 16)    │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 201, 64, 16)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 100, 32, 16)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_1              │ (None, 100, 32, 24)    │           528 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 32, 24)    │            96 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 100, 32, 24)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 50, 16, 24)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_2              │ (None, 50, 16, 32)     │           984 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 50, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 50, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 25, 8, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_3              │ (None, 25, 8, 48)      │         1,824 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 25, 8, 48)      │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 25, 8, 48)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 4, 48)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 48)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            49 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,192 (43.72 KB)
#  Trainable params: 3,650 (14.26 KB)
#  Non-trainable params: 240 (960.00 B)
#  Optimizer params: 7,302 (28.53 KB)

# %% [markdown]
# ## 셀 10. 학습(v3.1)

# %%
pos = int((y_train==1).sum())
neg = int((y_train==0).sum())
class_weight = {0: 1.0, 1: neg / (pos + 1e-6)}
print("class_weight:", class_weight)

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=[
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
    ],
)

cb = [
    tf.keras.callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_auc", mode="max", factor=0.5, patience=2, min_lr=1e-5),
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=64,
    class_weight=class_weight,
    callbacks=cb,
    verbose=1
)
# Out:
# class_weight: {0: 1.0, 1: 3.182890850762698}
# Epoch 1/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 29s 369ms/step - auc: 0.9360 - loss: 0.5120 - precision: 0.6888 - recall: 0.8781 - val_auc: 0.9567 - val_loss: 0.1985 - val_precision: 0.8690 - val_recall: 0.8690 - learning_rate: 0.0010
# Epoch 2/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - auc: 0.9771 - loss: 0.2980 - precision: 0.8173 - recall: 0.9437 - val_auc: 0.9632 - val_loss: 0.1872 - val_precision: 0.9058 - val_recall: 0.8621 - learning_rate: 0.0010
# Epoch 3/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9797 - loss: 0.2754 - precision: 0.8191 - recall: 0.9464 - val_auc: 0.9671 - val_loss: 0.1860 - val_precision: 0.8658 - val_recall: 0.8897 - learning_rate: 0.0010
# Epoch 4/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.9825 - loss: 0.2543 - precision: 0.8402 - recall: 0.9627 - val_auc: 0.9735 - val_loss: 0.1672 - val_precision: 0.8828 - val_recall: 0.8828 - learning_rate: 0.0010
# Epoch 5/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.9847 - loss: 0.2391 - precision: 0.8363 - recall: 0.9677 - val_auc: 0.9756 - val_loss: 0.1612 - val_precision: 0.9014 - val_recall: 0.8828 - learning_rate: 0.0010
# Epoch 6/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.9869 - loss: 0.2227 - precision: 0.8627 - recall: 0.9577 - val_auc: 0.9790 - val_loss: 0.1648 - val_precision: 0.8618 - val_recall: 0.9034 - learning_rate: 0.0010
# Epoch 7/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - auc: 0.9852 - loss: 0.2294 - precision: 0.8455 - recall: 0.9591 - val_auc: 0.9794 - val_loss: 0.1581 - val_precision: 0.8851 - val_recall: 0.9034 - learning_rate: 0.0010
# Epoch 8/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9868 - loss: 0.2148 - precision: 0.8674 - recall: 0.9687 - val_auc: 0.9806 - val_loss: 0.1751 - val_precision: 0.8457 - val_recall: 0.9448 - learning_rate: 0.0010
# Epoch 9/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9889 - loss: 0.1983 - precision: 0.8709 - recall: 0.9730 - val_auc: 0.9802 - val_loss: 0.1590 - val_precision: 0.8526 - val_recall: 0.9172 - learning_rate: 0.0010
# Epoch 10/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9888 - loss: 0.1960 - precision: 0.8697 - recall: 0.9683 - val_auc: 0.9814 - val_loss: 0.1612 - val_precision: 0.8544 - val_recall: 0.9310 - learning_rate: 0.0010
# Epoch 11/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - auc: 0.9893 - loss: 0.1917 - precision: 0.8680 - recall: 0.9761 - val_auc: 0.9820 - val_loss: 0.1667 - val_precision: 0.8562 - val_recall: 0.9448 - learning_rate: 0.0010
# Epoch 12/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9902 - loss: 0.1828 - precision: 0.8670 - recall: 0.9766 - val_auc: 0.9777 - val_loss: 0.1941 - val_precision: 0.8293 - val_recall: 0.9379 - learning_rate: 0.0010
# Epoch 13/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9887 - loss: 0.1876 - precision: 0.8715 - recall: 0.9775 - val_auc: 0.9813 - val_loss: 0.1688 - val_precision: 0.8562 - val_recall: 0.9448 - learning_rate: 0.0010
# Epoch 14/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9916 - loss: 0.1702 - precision: 0.8718 - recall: 0.9786 - val_auc: 0.9809 - val_loss: 0.1452 - val_precision: 0.8882 - val_recall: 0.9310 - learning_rate: 5.0000e-04
# Epoch 15/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9906 - loss: 0.1736 - precision: 0.8689 - recall: 0.9726 - val_auc: 0.9799 - val_loss: 0.1406 - val_precision: 0.9041 - val_recall: 0.9103 - learning_rate: 5.0000e-04
# Epoch 16/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9900 - loss: 0.1775 - precision: 0.8998 - recall: 0.9773 - val_auc: 0.9794 - val_loss: 0.1413 - val_precision: 0.8986 - val_recall: 0.9172 - learning_rate: 2.5000e-04

# %% [markdown]
# ## 셀 11. 평가 + threshold 선택(오탐 최소 기준)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve


val_prob = model.predict(X_val, verbose=0).reshape(-1)
test_prob = model.predict(X_test, verbose=0).reshape(-1)

print("val auc:", roc_auc_score(y_val, val_prob))
print("test auc:", roc_auc_score(y_test, test_prob))

fpr, tpr, thr = roc_curve(y_val, val_prob)

target_fpr = 0.01  # 1% 오탐 목표. 필요하면 0.005로 더 빡세게.
candidates = [(t, tp, fp) for t, tp, fp in zip(thr, tpr, fpr) if fp <= target_fpr]
if len(candidates) == 0:
    best_thr = 0.5
    best_tp = float(tpr[np.argmin(np.abs(thr-0.5))])
    best_fp = float(fpr[np.argmin(np.abs(thr-0.5))])
else:
    best_thr, best_tp, best_fp = sorted(candidates, key=lambda x: x[1], reverse=True)[0]

print("chosen threshold:", float(best_thr), "val_tpr:", float(best_tp), "val_fpr:", float(best_fp))

test_pred = (test_prob >= best_thr).astype(int)
cm = confusion_matrix(y_test, test_pred)
print("confusion_matrix:\n", cm)
print(classification_report(y_test, test_pred, digits=4))
# Out:
# val auc: 0.9817978699635063
# test auc: 0.9919565055485215
# chosen threshold: 0.9741973876953125 val_tpr: 0.6068965517241379 val_fpr: 0.008639308855291577
# confusion_matrix:
#  [[461   2]
#  [ 63  82]]
#               precision    recall  f1-score   support
#
#            0     0.8798    0.9957    0.9341       463
#            1     0.9762    0.5655    0.7162       145
#
#     accuracy                         0.8931       608
#    macro avg     0.9280    0.7806    0.8252       608
# weighted avg     0.9028    0.8931    0.8822       608

# %% [markdown]
# ## 셀 12. v3.1 저장(Keras + TFLite)

# %%
SAVE_KERAS = OUT_DIR / "v3_1_model.keras"
model.save(str(SAVE_KERAS))
print("saved:", SAVE_KERAS)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

SAVE_TFLITE = OUT_DIR / "v3_1_model.tflite"
SAVE_TFLITE.write_bytes(tflite_model)
print("saved:", SAVE_TFLITE)

# threshold도 같이 기록해두면 실전에서 편합니다.
thr_path = OUT_DIR / "v3_1_threshold.txt"
thr_path.write_text(str(float(best_thr)))
print("saved:", thr_path)

print("OUT_DIR:", OUT_DIR)
for p in sorted(OUT_DIR.rglob("*")):
    if p.is_file():
        print(" -", p.relative_to(OUT_DIR))
print("hard neg dir:", HARD_DIR)
print("hard neg files:", len(list(HARD_DIR.rglob("*.wav"))))
# Out:
# saved: /content/work/out/v3_1_model.keras
# Saved artifact at '/tmp/tmpjlwz0der'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 201, 64, 1), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   137462711777808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462711778000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462711779152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462711778192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462711777040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462711778768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712451920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712452304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712453456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712451536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712452112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712452496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712453072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712455760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712454608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712454224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712454032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712456528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712456720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712455376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712457104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712452688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137462712456336: TensorSpec(shape=(), dtype=tf.resource, name=None)
# saved: /content/work/out/v3_1_model.tflite
# saved: /content/work/out/v3_1_threshold.txt
# OUT_DIR: /content/work/out
#  - hard_negs_v3/hardneg_dish_102.00_p0.860.wav
#  - hard_negs_v3/hardneg_dish_1039.00_p0.713.wav
#  - hard_negs_v3/hardneg_dish_1041.50_p0.721.wav
#  - hard_negs_v3/hardneg_dish_1054.25_p0.929.wav
#  - hard_negs_v3/hardneg_dish_1069.75_p0.844.wav
#  - hard_negs_v3/hardneg_dish_1107.25_p0.846.wav
#  - hard_negs_v3/hardneg_dish_113.25_p0.905.wav
#  - hard_negs_v3/hardneg_dish_119.75_p0.844.wav
#  - hard_negs_v3/hardneg_dish_121.75_p0.972.wav
#  - hard_negs_v3/hardneg_dish_127.25_p0.806.wav
#  - hard_negs_v3/hardneg_dish_142.50_p0.810.wav
#  - hard_negs_v3/hardneg_dish_1605.75_p0.966.wav
#  - hard_negs_v3/hardneg_dish_161.75_p0.883.wav
#  - hard_negs_v3/hardneg_dish_1611.75_p0.830.wav
#  - hard_negs_v3/hardneg_dish_164.50_p0.761.wav
#  - hard_negs_v3/hardneg_dish_171.25_p0.705.wav
#  - hard_negs_v3/hardneg_dish_1716.50_p0.670.wav
#  - hard_negs_v3/hardneg_dish_174.00_p0.804.wav
#  - hard_negs_v3/hardneg_dish_2056.00_p0.761.wav
#  - hard_negs_v3/hardneg_dish_2058.50_p0.962.wav
#  - hard_negs_v3/hardneg_dish_2060.50_p0.753.wav
#  - hard_negs_v3/hardneg_dish_2063.50_p0.825.wav
#  - hard_negs_v3/hardneg_dish_207.75_p0.777.wav
#  - hard_negs_v3/hardneg_dish_2080.50_p0.863.wav
#  - hard_negs_v3/hardneg_dish_2089.75_p0.849.wav
#  - hard_negs_v3/hardneg_dish_209.75_p0.833.wav
#  - hard_negs_v3/hardneg_dish_2096.00_p0.966.wav
#  - hard_negs_v3/hardneg_dish_211.75_p0.810.wav
#  - hard_negs_v3/hardneg_dish_214.25_p0.913.wav
#  - hard_negs_v3/hardneg_dish_2141.25_p0.741.wav
#  - hard_negs_v3/hardneg_dish_2151.50_p0.814.wav
#  - hard_negs_v3/hardneg_dish_217.25_p0.996.wav
#  - hard_negs_v3/hardneg_dish_223.00_p0.697.wav
#  - hard_negs_v3/hardneg_dish_226.00_p0.808.wav
#  - hard_negs_v3/hardneg_dish_34.00_p0.713.wav
#  - hard_negs_v3/hardneg_dish_356.25_p0.877.wav
#  - hard_negs_v3/hardneg_dish_365.75_p0.723.wav
#  - hard_negs_v3/hardneg_dish_407.75_p0.784.wav
#  - hard_negs_v3/hardneg_dish_41.00_p0.971.wav
#  - hard_negs_v3/hardneg_dish_43.00_p0.917.wav
#  - hard_negs_v3/hardneg_dish_442.75_p0.773.wav
#  - hard_negs_v3/hardneg_dish_446.50_p0.779.wav
#  - hard_negs_v3/hardneg_dish_466.50_p0.724.wav
#  - hard_negs_v3/hardneg_dish_514.25_p0.747.wav
#  - hard_negs_v3/hardneg_dish_520.75_p0.886.wav
#  - hard_negs_v3/hardneg_dish_637.50_p0.735.wav
#  - hard_negs_v3/hardneg_dish_685.00_p0.701.wav
#  - hard_negs_v3/hardneg_dish_690.25_p0.744.wav
#  - hard_negs_v3/hardneg_dish_733.25_p0.893.wav
#  - hard_negs_v3/hardneg_dish_799.00_p0.727.wav
#  - hard_negs_v3/hardneg_dish_806.50_p0.670.wav
#  - hard_negs_v3/hardneg_dish_809.50_p0.736.wav
#  - hard_negs_v3/hardneg_dish_82.75_p0.921.wav
#  - hard_negs_v3/hardneg_dish_858.50_p0.912.wav
#  - hard_negs_v3/hardneg_dish_882.50_p0.866.wav
#  - hard_negs_v3/hardneg_dish_901.75_p0.857.wav
#  - hard_negs_v3/hardneg_dish_92.00_p0.675.wav
#  - hard_negs_v3/hardneg_dish_955.00_p0.675.wav
#  - hard_negs_v3/hardneg_dish_960.50_p0.855.wav
#  - hard_negs_v3/hardneg_dish_987.75_p0.766.wav
#  - hard_negs_v3/hardneg_noise1_172.50_p0.575.wav
#  - hard_negs_v3/hardneg_noise1_258.75_p0.626.wav
#  - hard_negs_v3/hardneg_noise1_26.00_p0.542.wav
#  - hard_negs_v3/hardneg_noise1_261.00_p0.529.wav
#  - hard_negs_v3/hardneg_noise1_272.25_p0.652.wav
#  - hard_negs_v3/hardneg_noise1_287.50_p0.608.wav
#  - hard_negs_v3/hardneg_noise1_310.00_p0.563.wav
#  - hard_negs_v3/hardneg_noise1_427.25_p0.565.wav
#  - hard_negs_v3/hardneg_noise1_463.25_p0.683.wav
#  - hard_negs_v3/hardneg_noise1_475.00_p0.850.wav
#  - hard_negs_v3/hardneg_noise1_477.25_p0.994.wav
#  - hard_negs_v3/hardneg_noise1_479.25_p0.984.wav
#  - hard_negs_v3/hardneg_noise1_481.25_p0.992.wav
#  - hard_negs_v3/hardneg_noise1_483.25_p0.994.wav
#  - hard_negs_v3/hardneg_noise1_485.50_p0.974.wav
#  - hard_negs_v3/hardneg_noise1_487.50_p0.974.wav
#  - hard_negs_v3/hardneg_noise1_542.25_p0.655.wav
#  - hard_negs_v3/hardneg_noise1_546.00_p0.546.wav
#  - hard_negs_v3/hardneg_noise1_548.25_p0.633.wav
#  - hard_negs_v3/hardneg_noise1_574.75_p0.541.wav
#  - hard_negs_v3/hardneg_noise1_578.00_p0.725.wav
#  - hard_negs_v3/hardneg_noise1_589.25_p0.684.wav
#  - hard_negs_v3/hardneg_noise1_607.75_p0.630.wav
#  - hard_negs_v3/hardneg_noise1_620.75_p0.561.wav
#  - hard_negs_v3/hardneg_noise1_651.50_p0.816.wav
#  - hard_negs_v3/hardneg_noise1_654.00_p0.868.wav
#  - hard_negs_v3/hardneg_noise1_656.25_p0.719.wav
#  - hard_negs_v3/hardneg_noise1_661.50_p0.628.wav
#  - hard_negs_v3/hardneg_noise1_68.00_p0.567.wav
#  - hard_negs_v3/hardneg_noise1_707.75_p0.587.wav
#  - hard_negs_v3/hardneg_noise1_721.00_p0.701.wav
#  - hard_negs_v3/hardneg_noise2_10.25_p0.846.wav
#  - hard_negs_v3/hardneg_noise2_101.50_p0.720.wav
#  - hard_negs_v3/hardneg_noise2_106.75_p0.655.wav
#  - hard_negs_v3/hardneg_noise2_111.50_p0.648.wav
#  - hard_negs_v3/hardneg_noise2_115.25_p0.636.wav
#  - hard_negs_v3/hardneg_noise2_117.25_p0.737.wav
#  - hard_negs_v3/hardneg_noise2_119.50_p0.612.wav
#  - hard_negs_v3/hardneg_noise2_123.50_p0.621.wav
#  - hard_negs_v3/hardneg_noise2_129.00_p0.782.wav
#  - hard_negs_v3/hardneg_noise2_13.00_p0.880.wav
#  - hard_negs_v3/hardneg_noise2_143.00_p0.601.wav
#  - hard_negs_v3/hardneg_noise2_149.50_p0.705.wav
#  - hard_negs_v3/hardneg_noise2_15.75_p0.815.wav
#  - hard_negs_v3/hardneg_noise2_153.00_p0.870.wav
#  - hard_negs_v3/hardneg_noise2_156.75_p0.887.wav
#  - hard_negs_v3/hardneg_noise2_18.00_p0.742.wav
#  - hard_negs_v3/hardneg_noise2_2.50_p0.774.wav
#  - hard_negs_v3/hardneg_noise2_22.75_p0.697.wav
#  - hard_negs_v3/hardneg_noise2_261.50_p0.676.wav
#  - hard_negs_v3/hardneg_noise2_37.25_p0.825.wav
#  - hard_negs_v3/hardneg_noise2_377.50_p0.718.wav
#  - hard_negs_v3/hardneg_noise2_380.25_p0.813.wav
#  - hard_negs_v3/hardneg_noise2_42.50_p0.594.wav
#  - hard_negs_v3/hardneg_noise2_422.50_p0.668.wav
#  - hard_negs_v3/hardneg_noise2_45.25_p0.759.wav
#  - hard_negs_v3/hardneg_noise2_50.25_p0.672.wav
#  - hard_negs_v3/hardneg_noise2_52.50_p0.693.wav
#  - hard_negs_v3/hardneg_noise2_537.50_p0.733.wav
#  - hard_negs_v3/hardneg_noise2_54.50_p0.786.wav
#  - hard_negs_v3/hardneg_noise2_544.50_p0.605.wav
#  - hard_negs_v3/hardneg_noise2_551.00_p0.608.wav
#  - hard_negs_v3/hardneg_noise2_554.75_p0.624.wav
#  - hard_negs_v3/hardneg_noise2_561.25_p0.826.wav
#  - hard_negs_v3/hardneg_noise2_563.75_p0.798.wav
#  - hard_negs_v3/hardneg_noise2_570.75_p0.667.wav
#  - hard_negs_v3/hardneg_noise2_574.50_p0.649.wav
#  - hard_negs_v3/hardneg_noise2_59.25_p0.616.wav
#  - hard_negs_v3/hardneg_noise2_6.00_p0.772.wav
#  - hard_negs_v3/hardneg_noise2_620.00_p0.756.wav
#  - hard_negs_v3/hardneg_noise2_625.00_p0.589.wav
#  - hard_negs_v3/hardneg_noise2_634.75_p0.940.wav
#  - hard_negs_v3/hardneg_noise2_637.25_p0.694.wav
#  - hard_negs_v3/hardneg_noise2_64.25_p0.809.wav
#  - hard_negs_v3/hardneg_noise2_646.50_p0.697.wav
#  - hard_negs_v3/hardneg_noise2_666.75_p0.659.wav
#  - hard_negs_v3/hardneg_noise2_67.00_p0.915.wav
#  - hard_negs_v3/hardneg_noise2_680.00_p0.601.wav
#  - hard_negs_v3/hardneg_noise2_683.75_p0.662.wav
#  - hard_negs_v3/hardneg_noise2_698.00_p0.678.wav
#  - hard_negs_v3/hardneg_noise2_702.75_p0.708.wav
#  - hard_negs_v3/hardneg_noise2_704.75_p0.590.wav
#  - hard_negs_v3/hardneg_noise2_710.00_p0.613.wav
#  - hard_negs_v3/hardneg_noise2_74.25_p0.682.wav
#  - hard_negs_v3/hardneg_noise2_8.25_p0.965.wav
#  - hard_negs_v3/hardneg_noise2_84.75_p0.823.wav
#  - hard_negs_v3/hardneg_noise2_88.25_p0.956.wav
#  - hard_negs_v3/hardneg_noise2_91.00_p0.636.wav
#  - hard_negs_v3/hardneg_noise2_93.50_p0.921.wav
#  - hard_negs_v3/hardneg_noise2_97.25_p0.742.wav
#  - hard_negs_v3/hardneg_noise2_99.50_p0.817.wav
#  - hard_negs_v3/hardneg_talk_1001.25_p0.836.wav
#  - hard_negs_v3/hardneg_talk_1006.25_p0.832.wav
#  - hard_negs_v3/hardneg_talk_1045.00_p0.875.wav
#  - hard_negs_v3/hardneg_talk_1089.75_p0.837.wav
#  - hard_negs_v3/hardneg_talk_1096.75_p0.961.wav
#  - hard_negs_v3/hardneg_talk_1149.25_p0.850.wav
#  - hard_negs_v3/hardneg_talk_1208.25_p0.850.wav
#  - hard_negs_v3/hardneg_talk_1213.25_p0.812.wav
#  - hard_negs_v3/hardneg_talk_1364.50_p0.845.wav
#  - hard_negs_v3/hardneg_talk_1441.00_p0.874.wav
#  - hard_negs_v3/hardneg_talk_1483.00_p0.858.wav
#  - hard_negs_v3/hardneg_talk_1498.50_p0.864.wav
#  - hard_negs_v3/hardneg_talk_1504.25_p0.971.wav
#  - hard_negs_v3/hardneg_talk_1518.75_p0.842.wav
#  - hard_negs_v3/hardneg_talk_1551.50_p0.868.wav
#  - hard_negs_v3/hardneg_talk_1814.00_p0.892.wav
#  - hard_negs_v3/hardneg_talk_1853.00_p0.820.wav
#  - hard_negs_v3/hardneg_talk_1855.75_p0.834.wav
#  - hard_negs_v3/hardneg_talk_186.00_p0.897.wav
#  - hard_negs_v3/hardneg_talk_192.50_p0.849.wav
#  - hard_negs_v3/hardneg_talk_1959.75_p0.833.wav
#  - hard_negs_v3/hardneg_talk_196.75_p0.804.wav
#  - hard_negs_v3/hardneg_talk_1981.25_p0.879.wav
#  - hard_negs_v3/hardneg_talk_1997.75_p0.860.wav
#  - hard_negs_v3/hardneg_talk_2004.00_p0.835.wav
#  - hard_negs_v3/hardneg_talk_2049.75_p0.798.wav
#  - hard_negs_v3/hardneg_talk_2063.25_p0.830.wav
#  - hard_negs_v3/hardneg_talk_2070.50_p0.804.wav
#  - hard_negs_v3/hardneg_talk_2078.00_p0.931.wav
#  - hard_negs_v3/hardneg_talk_2080.75_p0.811.wav
#  - hard_negs_v3/hardneg_talk_2088.75_p0.813.wav
#  - hard_negs_v3/hardneg_talk_2094.50_p0.869.wav
#  - hard_negs_v3/hardneg_talk_2117.50_p0.799.wav
#  - hard_negs_v3/hardneg_talk_213.75_p0.795.wav
#  - hard_negs_v3/hardneg_talk_2169.00_p0.872.wav
#  - hard_negs_v3/hardneg_talk_2209.00_p0.890.wav
#  - hard_negs_v3/hardneg_talk_229.25_p0.795.wav
#  - hard_negs_v3/hardneg_talk_243.25_p0.818.wav
#  - hard_negs_v3/hardneg_talk_285.25_p0.837.wav
#  - hard_negs_v3/hardneg_talk_316.25_p0.826.wav
#  - hard_negs_v3/hardneg_talk_352.25_p0.880.wav
#  - hard_negs_v3/hardneg_talk_362.25_p0.893.wav
#  - hard_negs_v3/hardneg_talk_365.50_p0.967.wav
#  - hard_negs_v3/hardneg_talk_445.50_p0.805.wav
#  - hard_negs_v3/hardneg_talk_486.25_p0.833.wav
#  - hard_negs_v3/hardneg_talk_527.25_p0.847.wav
#  - hard_negs_v3/hardneg_talk_550.50_p0.881.wav
#  - hard_negs_v3/hardneg_talk_592.00_p0.799.wav
#  - hard_negs_v3/hardneg_talk_631.50_p0.817.wav
#  - hard_negs_v3/hardneg_talk_633.50_p0.815.wav
#  - hard_negs_v3/hardneg_talk_688.75_p0.833.wav
#  - hard_negs_v3/hardneg_talk_699.00_p0.868.wav
#  - hard_negs_v3/hardneg_talk_732.50_p0.804.wav
#  - hard_negs_v3/hardneg_talk_748.25_p0.876.wav
#  - hard_negs_v3/hardneg_talk_791.25_p0.854.wav
#  - hard_negs_v3/hardneg_talk_795.25_p0.865.wav
#  - hard_negs_v3/hardneg_talk_799.00_p0.906.wav
#  - hard_negs_v3/hardneg_talk_806.25_p0.922.wav
#  - hard_negs_v3/hardneg_talk_815.25_p0.807.wav
#  - hard_negs_v3/hardneg_talk_835.00_p0.874.wav
#  - norm_stats.npz
#  - sneeze_ds_cnn.keras
#  - sneeze_ds_cnn_dynamic.tflite
#  - threshold.txt
#  - v3_1_model.keras
#  - v3_1_model.tflite
#  - v3_1_threshold.txt
# hard neg dir: /content/work/out/hard_negs_v3
# hard neg files: 211

# %%
# !ls work/out
# Out:
# hard_negs_v3		      sneeze_ds_cnn.keras  v3_1_model.tflite
# norm_stats.npz		      threshold.txt	   v3_1_threshold.txt
# sneeze_ds_cnn_dynamic.tflite  v3_1_model.keras

# %%
# !cp -r /content/work/out /content/drive/MyDrive/sneeze_models/
